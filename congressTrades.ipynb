# %%
import pandas as pd

from IPython.display import display

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

from congressTrades import CongressTrades
from tickers500 import Tickers500

# %%
tickers = Tickers500().tickers

# %%
ct = CongressTrades()
# Out:
# argument of type 'NoneType' is not iterable

# %%
ct.trades
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for junk in ct.junk_members:
    print(junk)
# Out:
# Abel
# Abolfazli
# Aboujaoude
# Adams
# Adams
# Addington
# Adolph
# Agwan
# Albertson-Corkery
# Alexander
# Allen
# Atkinson
# Almonord
# Altekar
# Altman
# Ammon
# Anderson
# Andrews
# Ansari
# Antropov
# Armendariz-Jackson
# Armey
# Armstead
# Ashby
# Atkins
# Austin
# Avion
# Avlon
# Ayers
# Baccam
# Bach
# Backie
# Baechler
# Baker
# Balekian
# Banweg
# Barca
# Barr
# Barrett
# Barry
# Barsoom
# Baugh
# Baumgartner
# Becker
# Bedell
# Begich
# Bell
# Belnome
# Bennett
# Bennett-Wolcott
# Bergmann
# Bernstein
# Berry
# Bhalla
# Bhandari

# %%
# List of congress members to download data for
# insider_traders = ['Pelosi', 'Mast', 'McCarthy', 'Schumer', 'McConnell', 'AOC', 'Boebert', 'Cruz', 'Hawley', 'Sanders', 'Warren', 'Harris', 'Biden']
insider_traders = ['Pelosi', 'Mast', 'Burr', 'Loeffler', 'Crenshaw', 'Fallon']
insider_traders
# Out:
# ['Pelosi', 'Mast', 'Burr', 'Loeffler', 'Crenshaw', 'Fallon']

# %%
congress_data = ct.get_congress_trading_data()

display(ct.members[540])
# Out:
# 'Nytes'

# %%
# Filter for trades by a specific member
trades = congress_data[congress_data['Last'] == "Pelosi"]

# Create a manifest of DocIDs
manifest = ct.get_doc_ids(trades.to_dict('records'))
display(manifest)
# Out:
# ['20024542', '20024625', '20025368', '20025535', '20025819']

# %%
for record in manifest[2:3]:
    try:
        pdf_df = ct.download_and_parse_pdf(record)
        display(pdf_df)
    except Exception as e:
        print(f"Failed to download PDF for {record}: {e}")
# Out:
#   Owner                Asset Ticker Transaction Type Transaction Date  \
# 0    SP        Broadcom Inc.   AVGO                P       06/24/2024
# 1    SP  NVIDIA Corporation    NVDA                P       06/26/2024
# 2    SP          Tesla, Inc.   TSLA                S       06/24/2024
# 3    SP           Visa Inc.       V      S (partial)       07/01/2024
#
#   Notification Date                   Amount Filing Status  \
# 0        06/24/2024  $1,000,001 - $5,000,000           New
# 1        06/26/2024  $1,000,001 - $5,000,000           New
# 2        06/24/2024      $250,001 - $500,000           New
# 3        07/01/2024    $500,001 - $1,000,000           New
#
#                                          Description
# 0  Purchased 20 call options with a strike price ...
# 1                           Purchased 10,000 shares.
# 2                                 Sold 2,500 shares.
# 3                                 Sold 2,000 shares.

# %%
trades = ct.get_trades_by_member(insider_traders)
# Out:
# Member:  Abel
# Member:  Abolfazli
# Member:  Aboujaoude
# Member:  Adams
# Member:  Adams
# Member:  Addington
# Member:  Addington
# Member:  Adolph
# Member:  Adolph
# Member:  Adolph
# Member:  Agwan
# Member:  Albertson-Corkery
# Member:  Albertson-Corkery
# Member:  Alexander
# Member:  Allen
# Member:  Allen
# Member:  Allen
# Member:  Allen
# Member:  Allen
# Member:  Allen
# Member:  Allen
# Member:  Allen
# Member:  Allen
# Member:  Almonord
# Member:  Altekar
# Member:  Altman
# Member:  Altman
# Member:  Ammon
# Member:  Anderson
# Member:  Anderson
# Member:  Anderson
# Member:  Anderson
# Member:  Anderson
# Member:  Anderson
# Member:  Andrews
# Member:  Andrews
# Member:  Andrews
# Member:  Andrews
# Member:  Ansari
# Member:  Ansari
# Member:  Antropov
# Member:  Armendariz-Jackson
# Member:  Armey
# Member:  Armstead
# Member:  Ashby
# Member:  Atkins
# Member:  Atkinson
# Member:  Auchincloss
# Member:  Auchincloss
# Member:  Austin
# Member:  Avion
# ...

# %%
display(trades)
# Out:
#     Member     DocID Owner                     Asset                   Ticker  \
# 0   Pelosi  20025819    SP            REOF XXVI, LLC  Asset-Backed Securities
# 1   Pelosi  20025535    SP    Microsoft Corporation                      MSFT
# 2   Pelosi  20025535    SP        NVIDIA Corporation                     NVDA
# 3   Pelosi  20025368    SP             Broadcom Inc.                     AVGO
# 4   Pelosi  20025368    SP       NVIDIA Corporation                      NVDA
# 5   Pelosi  20025368    SP               Tesla, Inc.                     TSLA
# 6   Pelosi  20025368    SP                Visa Inc.                         V
# 7   Pelosi  20024625    SP    Forge Investments, LLC  Asset-Backed Securities
# 8   Pelosi  20024542    SP  Palo Alto Networks, Inc.                     PANW
# 9   Pelosi  20024542    SP  Palo Alto Networks, Inc.                     PANW
# 10    Mast  20024743    DC          Amazon.com, Inc.                     AMZN
# ...
